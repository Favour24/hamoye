# %%
import numpy as np
import pandas as pd
fuel_data = pd.read_csv ('C:\\Users\\Adiva Berakah\\Desktop\\FAITH FAVOUR\\Hamoye Datascience\\fuel_ferc1.csv') 
A = [1,2,3,4,5,6]
B = [13, 21, 34]
A.append(B)

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
fuel_data
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
fuel_data.groupby('report_year').sum()
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1994                   131059     3.364163e+09         13138.051620
# 1995                   132277     4.458192e+09         12784.441067
# 1996                   118281     2.768693e+09         11726.508078
# 1997                   118553     3.077973e+09         11210.909740
# 1998                   121599     3.617070e+09         11850.394701
# 1999                   113634     3.445345e+09         11086.829479
# 2000                   152518     3.394100e+09         12665.204661
# 2001                   153935     3.147821e+09         11351.712598
# 2002                   145027     2.585502e+09         10007.324112
# 2003                   149317     2.287121e+09         10176.936748
# 2004                   144379     2.124797e+09          9932.250643
# 2005                   153585     2.244703e+09         10324.548458
# 2006                   145653     2.432879e+09         10115.646333
# ...

# %%
fuel_cost_per_unit_burn_per_year = fuel_data.groupby('report_year')['fuel_cost_per_unit_burned'].sum()
fuel_cost_per_unit_burn_per_year
# Out:
# report_year
# 1994    263292.115
# 1995    425661.488
# 1996     86425.275
# 1997    163533.452
# 1998    140238.656
# 1999    126056.285
# 2000    326495.434
# 2001    180365.641
# 2002    121921.135
# 2003    149175.726
# 2004    184637.699
# 2005    135924.139
# 2006    188142.032
# 2007    256114.312
# 2008    314312.022
# 2009    263584.566
# 2010    331581.467
# 2011    374175.603
# 2012    321693.544
# 2013    306933.236
# 2014    518002.469
# 2015    260060.984
# 2016    255484.814
# 2017    244557.823
# 2018    221575.426
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#percentage_change_in_fuel_cost_per_unit_burn
fuel_cost_per_unit_burn_1994 = fuel_cost_per_unit_burn_per_year[0:1][1994]
fuel_cost_per_unit_burn_1998 = fuel_cost_per_unit_burn_per_year[4:5][1998]
percentage_change_in_fuel_cost_per_unit_burn = ((fuel_cost_per_unit_burn_1998 - fuel_cost_per_unit_burn_1994)/fuel_cost_per_unit_burn_1994) * 100
percentage_change_in_fuel_cost_per_unit_burn
# Out:
# -46.73647708743574

# %%
fuel_data.groupby('report_year').min()
# Out:
#                             record_id  utility_id_ferc1    plant_name_ferc1  \
# report_year
# 1994          f1_fuel_1994_12_100_0_1                 1            (1)sta98
# 1995          f1_fuel_1995_12_100_0_1                 1    (n) contra costa
# 1996          f1_fuel_1996_12_100_0_1                 1      * harrison (3)
# 1997          f1_fuel_1997_12_100_0_1                 1    * ar nuclear one
# 1998          f1_fuel_1998_12_100_0_1                 1  *bridgeport harbor
# 1999          f1_fuel_1999_12_100_0_1                 1    *dolet hills (3)
# 2000          f1_fuel_2000_12_100_0_1                 1    *dolet hills (3)
# 2001          f1_fuel_2001_12_100_0_1                 1    *dolet hills (3)
# 2002          f1_fuel_2002_12_100_0_1                 1    *dolet hills (3)
# 2003          f1_fuel_2003_12_100_0_1                 1    *dolet hills (3)
# 2004          f1_fuel_2004_12_100_0_1                 1    *dolet hills (3)
# ...

# %%
average_fuel_cost_per_unit_delivered_per_year = fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
average_fuel_cost_per_unit_delivered_per_year
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
year_with_highest_average_fuel_cost_per_unit_delivered= average_fuel_cost_per_unit_delivered_per_year[3:4]
year_with_highest_average_fuel_cost_per_unit_delivered
# Out:
# report_year
# 1997    11140.197239
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
fuel_data.notnull().sum()
# Out:
# record_id                       29523
# utility_id_ferc1                29523
# report_year                     29523
# plant_name_ferc1                29523
# fuel_type_code_pudl             29523
# fuel_unit                       29343
# fuel_qty_burned                 29523
# fuel_mmbtu_per_unit             29523
# fuel_cost_per_unit_burned       29523
# fuel_cost_per_unit_delivered    29523
# fuel_cost_per_mmbtu             29523
# dtype: int64

# %%
#skewness of fuel quantity burned
fuel_qty_burned_per_year = fuel_data['fuel_qty_burned'].skew()
fuel_qty_burned_per_year. round(2)
# Out:
# 15.85

# %%
# Kurtoise of fuel quantity burned
fuel_qty_burned_per_year = fuel_data['fuel_qty_burned'].kurt()
fuel_qty_burned_per_year. round(2)
# Out:
# 651.37

# %%
fuel_data['fuel_mmbtu_per_unit'].std()
# Out:
# 10.600220307806886

# %%
fuel_data['fuel_mmbtu_per_unit'].describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
fuel_data.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].sum()[4:5]
# Out:
# fuel_type_code_pudl
# other    3048.394
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
A = [1,2,3,4,5,6] 
B = [13, 21, 34]
A.append(B)
A
# Out:
# [1, 2, 3, 4, 5, 6, [13, 21, 34]]

# %%
A = [1,2,3,4,5,6] 
B = [13, 21, 34]
A.extend(B)
A
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]
